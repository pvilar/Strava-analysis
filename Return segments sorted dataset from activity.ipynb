# %%
import os

import pandas as pd

from pystrava.utils import get_tokens
from pystrava.segments import sort_segments_from_activity

# %%
pd.set_option('display.max_columns', None)

# %%
TOKENS_FILEPATH = os.getenv("TOKENS_FILEPATH")
CLIENT_ID = os.getenv("CLIENT_ID")
CLIENT_SECRET = os.getenv("CLIENT_SECRET")

# %%
strava_tokens = get_tokens(CLIENT_ID, CLIENT_SECRET, TOKENS_FILEPATH)

# %%
ACTIVITY_ID = '4074378152'
GENDER = 'man'

# %%
df_segments = sort_segments_from_activity(
    ACTIVITY_ID, gender=GENDER, strava_tokens=strava_tokens)
# Out:
# Loading segments
# Segments loaded successfully
# Sorting segments...
# Sorting segments...done!

# %%
df_segments
# Out:
#                      id  resource_state  \
# 40  2741743541459818574               2
# 26  2741743541453710414               2
# 23  2741743541457778766               2
# 39  2741743541460172878               2
# 43  2741743541458024526               2
# 60  2741743541467367502               2
# 18  2741743541454813262               2
# 50  2741743541465119822               2
# 36  2741743541459286094               2
# 11  2741743541451136078               2
#
#                                                  name  elapsed_time  \
# 40                    Sterrati Purmerbos (midden) N-Z           164
# 26                                    Dijk naar bocht           122
# 23                              Tijdrit Marken-minder           740
# 39                                         Burgergolf           231
# 43  Purmerend Groenewegbrug t/m Mandelabrug (by St...           171
# 60                      Schellingwoudebrug (Full) N-S            94
# 18                               Sprint bordje Uitdam            34
# 50                               HGI Sprint Landsmeer            49
# 36                             Eindsprint N244 - Edam            79
# 11                               Uitdammerdijk Sprint           104
#
#     moving_time            start_date      start_date_local  distance  \
# 40          164  2020-09-17T17:25:17Z  2020-09-17T19:25:17Z  1376.000
# 26          122  2020-09-17T16:44:26Z  2020-09-17T18:44:26Z  1620.800
# 23          627  2020-09-17T16:43:21Z  2020-09-17T18:43:21Z  6456.600
# 39          216  2020-09-17T17:20:40Z  2020-09-17T19:20:40Z  1872.200
# 43          171  2020-09-17T17:35:05Z  2020-09-17T19:35:05Z  1293.900
# 60           94  2020-09-17T18:07:25Z  2020-09-17T20:07:25Z   931.700
# 18           34  2020-09-17T16:27:47Z  2020-09-17T18:27:47Z   320.400
# 50           49  2020-09-17T17:49:09Z  2020-09-17T19:49:09Z   454.300
# 36           79  2020-09-17T17:11:54Z  2020-09-17T19:11:54Z   675.600
# 11          104  2020-09-17T16:15:06Z  2020-09-17T18:15:06Z   881.874
#
#     start_index  end_index  device_watts  average_watts  pr_rank  \
# 40         1278       1329         False          127.6      2.0
# 26          683        716         False          502.2      1.0
# 23          660        836         False          249.7      2.0
# 39         1208       1265         False          127.4      1.0
# 43         1403       1452         False          116.6      1.0
# 60         1901       1927         False          241.2      2.0
# 18          452        460         False          188.1      NaN
# 50         1594       1604         False          183.9      1.0
# 36         1082       1095         False          126.9      2.0
# 11          268        293         False          120.7      NaN
#
#                                  achievements  hidden  activity.id  \
# 40  [{'type_id': 3, 'type': 'pr', 'rank': 2}]   False   4074378152
# 26  [{'type_id': 3, 'type': 'pr', 'rank': 1}]   False   4074378152
# 23  [{'type_id': 3, 'type': 'pr', 'rank': 2}]   False   4074378152
# 39  [{'type_id': 3, 'type': 'pr', 'rank': 1}]   False   4074378152
# 43  [{'type_id': 3, 'type': 'pr', 'rank': 1}]   False   4074378152
# 60  [{'type_id': 3, 'type': 'pr', 'rank': 2}]   False   4074378152
# 18                                         []   False   4074378152
# 50  [{'type_id': 3, 'type': 'pr', 'rank': 1}]   False   4074378152
# 36  [{'type_id': 3, 'type': 'pr', 'rank': 2}]   False   4074378152
# 11                                         []   False   4074378152
#
#     activity.resource_state  athlete.id  athlete.resource_state  segment.id  \
# 40                        1    11827719                       1     8727056
# 26                        1    11827719                       1    12258382
# 23                        1    11827719                       1     9607336
# 39                        1    11827719                       1    18162255
# 43                        1    11827719                       1     9451680
# 60                        1    11827719                       1    17796309
# 18                        1    11827719                       1    15460783
# 50                        1    11827719                       1    10090446
# 36                        1    11827719                       1    25047018
# 11                        1    11827719                       1     1822129
#
#     segment.resource_state                                       segment.name  \
# 40                       2                    Sterrati Purmerbos (midden) N-Z
# 26                       2                                    Dijk naar bocht
# 23                       2                              Tijdrit Marken-minder
# 39                       2                                         Burgergolf
# 43                       2  Purmerend Groenewegbrug t/m Mandelabrug (by St...
# 60                       2                      Schellingwoudebrug (Full) N-S
# 18                       2                               Sprint bordje Uitdam
# 50                       2                               HGI Sprint Landsmeer
# 36                       2                             Eindsprint N244 - Edam
# 11                       2                               Uitdammerdijk Sprint
#
#    segment.activity_type  segment.distance  segment.average_grade  \
# 40                  Ride          1376.000                   -0.3
# 26                  Ride          1620.800                    0.1
# 23                  Ride          6456.600                    0.0
# 39                  Ride          1872.200                    0.2
# 43                  Ride          1293.900                    0.1
# 60                  Ride           931.700                   -0.1
# 18                  Ride           320.400                   -0.3
# 50                  Ride           454.300                    0.2
# 36                  Ride           675.600                    0.1
# 11                  Ride           881.874                   -0.1
#
#     segment.maximum_grade  segment.elevation_high  segment.elevation_low  \
# 40                    2.2                     2.4                   -2.7
# 26                    2.8                   -22.4                  -24.6
# 23                   18.7                     7.0                   -9.5
# 39                    1.6                     0.3                   -4.1
# 43                    3.1                     2.0                   -1.2
# 60                    1.3                     2.5                   -0.2
# 18                   -0.1                    77.8                   76.8
# 50                    1.2                    -0.3                   -2.1
# 36                    0.7                    -0.4                   -1.4
# 11                    1.5                     0.2                   -1.8
#
#            segment.start_latlng        segment.end_latlng  \
# 40        [52.491648, 4.991622]     [52.482653, 4.982462]
# 26        [52.448445, 5.094559]     [52.434595, 5.088749]
# 23        [52.455245, 5.103189]     [52.447287, 5.048744]
# 39        [52.506536, 5.008134]     [52.493234, 4.994342]
# 43        [52.490664, 4.957417]     [52.487874, 4.948467]
# 60        [52.381912, 4.970232]     [52.375015, 4.962753]
# 18        [52.414038, 5.067404]     [52.416829, 5.067932]
# 50        [52.430342, 4.950359]     [52.426252, 4.950253]
# 36        [52.503486, 5.039752]      [52.508981, 5.04333]
# 11  [52.381328333, 5.002703333]  [52.384845, 5.014303333]
#
#    segment.elevation_profile  segment.start_latitude  segment.start_longitude  \
# 40                      None               52.491648                 4.991622
# 26                      None               52.448445                 5.094559
# 23                      None               52.455245                 5.103189
# 39                      None               52.506536                 5.008134
# 43                      None               52.490664                 4.957417
# 60                      None               52.381912                 4.970232
# 18                      None               52.414038                 5.067404
# 50                      None               52.430342                 4.950359
# 36                      None               52.503486                 5.039752
# 11                      None               52.381328                 5.002703
#
#     segment.end_latitude  segment.end_longitude  segment.climb_category  \
# 40             52.482653               4.982462                       0
# 26             52.434595               5.088749                       0
# 23             52.447287               5.048744                       0
# 39             52.493234               4.994342                       0
# 43             52.487874               4.948467                       0
# 60             52.375015               4.962753                       0
# 18             52.416829               5.067932                       0
# 50             52.426252               4.950253                       0
# 36             52.508981               5.043330                       0
# 11             52.384845               5.014303                       0
#
#    segment.city  segment.state  segment.country  segment.private  \
# 40    Purmerend  Noord-Holland      Netherlands            False
# 26       Uitdam  Noord-Holland      Netherlands            False
# 23       Marken  Noord-Holland      Netherlands            False
# 39    Purmerend  Noord-Holland      Netherlands            False
# 43    Purmerend  Noord-Holland      Netherlands            False
# 60    Amsterdam  Noord-Holland      Netherlands            False
# 18    Amsterdam  Noord-Holland      Netherlands            False
# 50    Landsmeer  Noord-Holland      Netherlands            False
# 36         Edam  Noord-Holland      Netherlands            False
# 11    Amsterdam  Noord-Holland  The Netherlands            False
#
#     segment.hazardous  segment.starred  segment_time_delta
# 40              False            False            0.281250
# 26              False            False            0.326087
# 23              False            False            0.367837
# 39              False            False            0.383234
# 43              False            False            0.461538
# 60              False            False            0.566667
# 18              False            False            0.789474
# 50              False            False            0.884615
# 36              False            False            0.926829
# 11              False            False            1.039216

# %% [markdown]
# Improvements:
# * return only top K segments (high chances to exceed the rate limit in the request to get leader elapsed time for every segment
# * return segments that are closer than a certain threshold to the leader (otherwise return nothing)
